# %% [markdown]
# ![](./images/logo2.png)
#
# # Belajar Visualisasi Data Dasar dengan Matplotlib
#
# - Dataset: Titanic Dataset (sumber: [Kaggle](https://www.scipy2019.scipy.org/))
# - Kurikulum:  [SciPy Conference 2019](https://www.scipy2019.scipy.org/)

# %% [markdown]
# ## Import Modules

# %%
import matplotlib
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 

# %matplotlib inline

print(f'Matplotlib: {matplotlib.__version__}')
print(f'pandas: {pd.__version__}')
print(f'numpy: {np.__version__}')
# Out:
# Matplotlib: 3.1.3
# pandas: 1.0.1
# numpy: 1.18.1

# %% [markdown]
# - `matplotlib` adalah module visualisasi data dalam pemrograman Python
# - `pandas` adalah module analisis data dalam pemrograman Python
# - `numpy` adalah module operasi numerik dalam pemrograman Python
# - `%matplotlib inline` akan mengarahkan output dari `matplotlib` ke `Jupyter Notebook`

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UvpBJZ_UKk0')

# %% [markdown]
# ## Titanic Dataset

# %%
df = pd.read_csv('./data/titanicfull.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# ```pd.read_csv()``` adalah function yang untuk memuat (load) data yang tersimpan dalam format ```csv``` ke dalam format ```DataFrame```.

# %% [markdown]
# | Variable | 	Definition | 	Key |
# |-----------:|-------------:|-------:|
# | survival | 	Survival 	| 0 = No, 1 = Yes |
# | pclass | Ticket class 	| 1 = 1st, 2 = 2nd, 3 = 3rd |
# | sex 	| sex | |
# | age 	| age in years 	 | |
# | sibsp |	# of siblings / spouses on board 	| |
# | parch |	# of parents / children on board  | |
# | ticket| 	Ticket number ||
# | fare  |	Passenger fare 	||
# | cabin |	Cabin number 	||
# | embarked |Port of Embarkation | 	C = Cherbourg, Q = Queenstown, S = Southampton|

# %% [markdown]
# ## Uji coba plotting

# %%
fig, ax = plt.subplots()
ax.plot(np.sort(df['age']), marker='o', markersize=1)

# %% [markdown]
# ## Anatomi Figure pada Matplotlib

# %% [markdown]
# ![](./images/mpl_anatomy.png)

# %% [markdown]
# ## Membuat Figure

# %%
plt.figure()

# %% [markdown]
# ```plt.figure()``` adalah factory function yang menghasilkan/mengembalikan sebuah object ```Figure```.

# %% [markdown]
# ## Membuat Plotting Surface (Figure + Axes)

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc747dea650>)

# %% [markdown]
# `plt.subplots()` adalah factory function yang menghasilkan/mengembalikan dua buah object, yaitu `Figure` dan `Axes`.

# %% [markdown]
# ## Plotting Surface (Figure + Axes)

# %%
fig, ax = plt.subplots()

# %% [markdown]
# - Variable `fig` digunakan untuk menampung object `Figure`
# - variable `ax` digunakan untuk menampung object `Axes`

# %% [markdown]
# ## Mengatur Ukuran Figure (Figure Size)

# %%
fig, ax = plt.subplots(figsize=(4,2))

# %% [markdown]
# `figsize` merepresentasikan (`width`, `height`) sama seperti ukuran kertas

# %% [markdown]
# ## Memulai Plotting Sederhana

# %%
fig, ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')

# %% [markdown]
# Karakter uderscore `_` digunakan sebagai don't care character

# %%
YouTubeVideo('Y9mRkPs_LpE')

# %% [markdown]
# ## Menyertakan Label

# %%
fig, ax = plt.subplots()
_ = ax.set_title ('Titanic Data Set')
# _ = ax.set_title (r'Titanic Data Set $\alpha$')
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')

_ = ax.set_ylabel('Ages')
_ = ax.set_xlabel('Passengers')

# %% [markdown]
# ## Mengenal Tick Locators

# %%
fig, ax = plt.subplots()
_ = ax.set_title ('Titanic Data Set')
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')
_ = ax.set_ylabel('Ages')
_ = ax.set_xlabel('Passengers')

_ = ax.set_yticks([15, 25, 55, 64])

# %% [markdown]
# [Referensi Tick Locators](https://matplotlib.org/3.1.1/gallery/ticks_and_spines/tick-locators.html)

# %% [markdown]
# ## Mengenal Tick Formatters

# %%
fig, ax = plt.subplots()
_ = ax.set_title ('Titanic Data Set')
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')
_ = ax.set_ylabel('Ages')
_ = ax.set_xlabel('Passengers')

_ = ax.set_yticks([15, 25, 55, 64])
_ = ax.set_yticklabels(['children', 'youth', 'adults', 'seniors'])

# %% [markdown]
# [Referensi Tick Formatters](https://matplotlib.org/3.1.1/gallery/ticks_and_spines/tick-formatters.html)

# %% [markdown]
# ## Studi Kasus: Visualisasi Fares
#
# - First Class Suite: £870
# - First Class Berth: £30
# - Second Class: £12
# - Third Class: £3

# %%
fig, ax = plt.subplots()
_ = ax.set_title ('Titanic Data Set')
_ = ax.plot(np.sort(df['fare']), marker='o', markersize=1, linestyle='')
_ = ax.set_ylabel('Fares')
_ = ax.set_xlabel('Passengers')
_ = ax.set_yticks([3, 12, 30, 870])
_ = ax.set_yticklabels(['3rd', '2nd', '1stb', '1sts'])

# %% [markdown]
# ## Mengenal Log Scale

# %%
fig, ax = plt.subplots()
_ = ax.set_title ('Titanic Data Set')
_ = ax.plot(np.sort(df['fare']), marker='o', markersize=1, linestyle='')
_ = ax.set_ylabel('Fares')
_ = ax.set_xlabel('Passengers')

_ = ax.set_yscale('log')
_ = ax.set_yticks([3, 12, 30, 870])
_ = ax.set_yticklabels(['3rd', '2nd', '1stb', '1sts'])
# _ = ax.set_yscale('log')

# %% [markdown]
# ## Mengenal Multiple Axes [1/3]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
_ = fig.suptitle('Super Title')
_ = ax1.set_title('Judul Axes 1')
_ = ax2.set_title('Judul Axes 2')

# %% [markdown]
# - Sebuah ```Figure``` dapat memiliki lebih dari satu ```Axes```
# - ```ncols``` digunakan untuk mengatur jumlah kolom
# - ```(ax1, ax2)``` digunakan untuk menampung kedua objects ```Axes```
# - ```fig.suptitle()``` digunakan untuk mengatur judul ```Figure```
# - ```ax1.set_title()``` digunakan untuk mengatur judul ```Axes```

# %% [markdown]
# ## Mengenal Multiple Axes [2/3]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2)
_ = fig.suptitle('Super Title')

# %% [markdown]
# ```nrows``` digunakan untuk mengatur jumlah baris

# %% [markdown]
# ## Mengenal Multiple Axes [3/3]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
_ = fig.suptitle('Super Title')

# %% [markdown]
# Penggunaan ```ncols``` dan ```nrows``` dapat dipadukan

# %% [markdown]
# ## Plotting pada Multiple Axes

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
_ = fig.suptitle("Titanic Data Set")

_ = ax1.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')
_ = ax1.set_title('Ages')
_ = ax1.set_xlabel('Passengers')
# _ = ax1.set_ylabel('Ages')
_ = ax1.set_yticks([15,25, 55, 64])
_ = ax1.set_yticklabels(['children', 'youth', 'adults', 'seniors'])

_ = ax2.plot(np.sort(df['fare']), marker='o', markersize=1, linestyle='')
_ = ax2.set_title('Fares')
_ = ax2.set_xlabel('Passengers')
# _ = ax2.set_ylabel('Fares')
_ = ax2.set_yscale('log')
_ = ax2.set_yticks([3, 12, 30, 870])
_ = ax2.set_yticklabels(['3rd', '2nd', '1stb', '1sts'])

# %% [markdown]
# ## Mengenal Constrained Layout

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, constrained_layout=True)
_ = fig.suptitle("Titanic Data Set")

_ = ax1.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')
_ = ax1.set_title('Ages')
_ = ax1.set_xlabel('Passengers')
_ = ax1.set_ylabel('Ages')
_ = ax1.set_yticks([15,25, 55, 64])
_ = ax1.set_yticklabels(['children', 'youth', 'adults', 'seniors'])

_ = ax2.plot(np.sort(df['fare']), marker='o', markersize=1, linestyle='')
_ = ax2.set_title('Fares')
_ = ax2.set_xlabel('Passengers')
_ = ax2.set_ylabel('Fares')
_ = ax2.set_yscale('log')
_ = ax2.set_yticks([3, 12, 30, 870])
_ = ax2.set_yticklabels(['3rd', '2nd', '1stb', '1sts'])

# %% [markdown]
# - ```constrained_layout``` digunakan untuk memastikan tidak ada element dalam plotting yang tumpang tindih (overlap)
# - [Referensi Constrained Layout](https://matplotlib.org/3.1.1/tutorials/intermediate/constrainedlayout_guide.html)

# %% [markdown]
# ## Mengenal GridSpec

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, constrained_layout=True, gridspec_kw={'width_ratios':[1,3]})
_ = fig.suptitle("Titanic Data Set")

_ = ax1.plot(np.sort(df['age']), marker='o', markersize=1, linestyle='')
_ = ax1.set_title('Ages')
_ = ax1.set_xlabel('Passengers')
_ = ax1.set_ylabel('Ages')
_ = ax1.set_yticks([15,25, 55, 64])
_ = ax1.set_yticklabels(['children', 'youth', 'adults', 'seniors'])

_ = ax2.plot(np.sort(df['fare']), marker='o', markersize=1, linestyle='')
_ = ax2.set_title('Fares')
_ = ax2.set_xlabel('Passengers')
_ = ax2.set_ylabel('Fares')
_ = ax2.set_yscale('log')
_ = ax2.set_yticks([3, 12, 30, 870])
_ = ax2.set_yticklabels(['3rd', '2nd', '1stb', '1sts'])

# %% [markdown]
# ## Mengenal Line Plot

# %%
x = np.linspace(0, 2*np.pi, 100)
sin_x = np.sin(x)

fig, ax = plt.subplots()
_ = ax.plot(x, sin_x)

# %% [markdown]
# ## Mengenal Aspect Ratio

# %%
fig, ax = plt.subplots()
_ = ax.plot(x, sin_x)
_ = ax.set_aspect('equal')

# %% [markdown]
# ## Mengenal Marker

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = ax.plot(x, sin_x, marker='*')
_ = ax.set_aspect('equal')

# %% [markdown]
# [Referensi Marker](https://matplotlib.org/examples/lines_bars_and_markers/marker_reference.html)

# %% [markdown]
# ## Pengaturan Warna

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = ax.plot(x, sin_x, marker='*', markerfacecolor='white', markeredgecolor='blue', color='red')
_ = ax.set_aspect('equal')

# %% [markdown]
# - `markerfacecolor` digunakan untuk mengatur warna marker
# - `markeredgecolor` digunakan untuk mengatur warna garis tepi marker
# - `color` digunakan untuk mengatur warna plat utama, dalam kasus ini adalah gari (line)

# %% [markdown]
# ## Pengaturan Ukuran

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = ax.plot(x, sin_x, marker='*', markersize=20, linewidth=20)
_ = ax.set_aspect('equal')

# %% [markdown]
# - `markersize` digunakan untuk mengatur ukuran marker
# - `linewidth` digunakan untuk mengatur ukuran garis (line)

# %% [markdown]
# ## Mengenal Line Style

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = ax.plot(x, sin_x, linewidth=5, linestyle='-.')
_ = ax.set_aspect('equal')

# %% [markdown]
# [Referensi Line Style](https://matplotlib.org/gallery/lines_bars_and_markers/linestyles.html#sphx-glr-gallery-lines-bars-and-markers-linestyles-py)

# %% [markdown]
# ## Mengenal Legend

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = ax.plot(x, sin_x, markersize=20, linestyle='-.', color='red', label='sin')
_ = ax.plot(x, np.cos(x), markersize=20, linestyle='-', color='blue', label='cos')
_ = ax.set_aspect('equal')
_ = ax.legend()

# %% [markdown]
# [Referensi Legend](https://matplotlib.org/3.1.0/tutorials/intermediate/legend_guide.html)

# %% [markdown]
# ## Menangani Missing Values

# %%
df = df.dropna()
df.head()

# %%
YouTubeVideo('xepdUmknZYs')

# %% [markdown]
# ## Mengenal Scatter Plot

# %%
fig, ax = plt.subplots()

_ = ax.scatter(df['age'], df['fare'])

_ = ax.set_title('Titanic Dataset')
_ = ax.set_xlabel('Age')
_ = ax.set_ylabel('Fare')

# %% [markdown]
# ## Mengenal `kwarg`

# %%
fig, ax = plt.subplots()

_ = ax.scatter('age', 'fare', data=df)

_ = ax.set_title('Titanic Dataset')
_ = ax.set_xlabel('Age')
_ = ax.set_ylabel('Fare')

# %% [markdown]
# ## Pengaturan Label dengan Function `set()`

# %%
fig, ax = plt.subplots()
_ = ax.scatter('age', 'fare', data=df)

# _ = ax.set_title('Titanic Dataset')
# _ = ax.set_xlabel('age')
# _ = ax.set_ylabel('fare')

_ = ax.set(xlabel='age', ylabel='fare', title='Titanic Dataset')

# %% [markdown]
# ## Pengaturan Warna

# %%
fig, ax = plt.subplots()

_ = ax.scatter('age', 'fare', color='red', data=df)

_ = ax.set(xlabel='age', ylabel='fare', title='Titanic Dataset')

# %% [markdown]
# ## Menampilkan Variable Ketiga pada Scatter Plot

# %%
fig, ax = plt.subplots()

_ = ax.scatter('age', 'fare', c='survived', data=df)

_ = ax.set(xlabel='age', ylabel='fare', title='Titanic Dataset')

# %% [markdown]
# ## Mengenal Color Maps

# %%
fig, ax = plt.subplots()

_ = ax.scatter('age', 'fare', c='survived', cmap='tab10', data=df)

_ = ax.set(xlabel='age', ylabel='fare', title='Titanic Dataset')

# %% [markdown]
# [Referensi Color Maps](https://matplotlib.org/examples/color/colormaps_reference.html)

# %% [markdown]
# ## Mengenal `ListedColormap`

# %%
import matplotlib.colors as mcolors

cmap = mcolors.ListedColormap(['red', 'green'])

fig, ax = plt.subplots()

_ = ax.scatter('age', 'fare', c='survived', cmap=cmap, data=df)

_ = ax.set(xlabel='age', ylabel='fare', title='Titanic Dataset')

# %% [markdown]
# ## Menyertakan Legend

# %%
fig, ax = plt.subplots()
sc = ax.scatter('age', 'fare', c='survived', cmap=cmap, data=df)
_ = ax.set(xlabel='Age', ylabel='Fare')

_ = ax.legend(*sc.legend_elements())

# %% [markdown]
# ## Mengenal Custom Legend

# %%
fig, ax = plt.subplots()
sc = ax.scatter('age', 'fare', c='survived', cmap=cmap, data=df)
_ = ax.set(xlabel='Age', ylabel='Fare')

_ = ax.legend(handles=sc.legend_elements()[0], labels=['Died', 'Survived'])

# %% [markdown]
# ## Mengenal Histogram

# %%
df.head()

# %%
fig, ax = plt.subplots()

(counts, edges, _) = ax.hist('age', bins='auto', data=df)

# %% [markdown]
# ## Mengenal Custom Bins

# %%
fig, ax = plt.subplots()

custom_bins = [0, 15,25, 55, 64]
(counts, edges, _) = ax.hist('age', bins=custom_bins, data=df)

_ = ax.set_xticks(custom_bins)

# %% [markdown]
# ## Pengaturan `facecolor` dan `edgecolor`

# %%
fig, ax = plt.subplots()

custom_bins = [0, 15,25, 55, 64]
(counts, edges, _) = ax.hist('age', bins=custom_bins, data=df,
                            facecolor='white', edgecolor='black')
_ = ax.set_xticks(custom_bins)

# %% [markdown]
# ## Mengenal `groupby`

# %%
fig, ax = plt.subplots()
custom_bins = [0, 15,25, 55, 64]

for label, gdf in df.groupby('sex'):
    ax.hist('age', bins=custom_bins, data=gdf, 
            label=label, alpha=.5)
    
_ = ax.set_xticks(custom_bins)
_ = ax.legend()

# %% [markdown]
# ## Mengenal `histtype`

# %%
fig, ax = plt.subplots()
custom_bins = [0, 15,25, 55, 64]

for label, gdf in df.groupby('sex'):
    ax.hist('age', bins=custom_bins, data=gdf, 
            label=label, alpha=.5, histtype='step')
    
_ = ax.set_xticks(custom_bins)
_ = ax.legend()

# %% [markdown]
# [Referensi `histtype`](https://matplotlib.org/3.2.1/gallery/statistics/histogram_histtypes.html)

# %% [markdown]
# ## Mengenal Pie Chart

# %%
survived = df['survived'].value_counts()
survived

# %%
fig, ax =plt.subplots()

_ = ax.pie(x=survived.values, 
           labels=['survived', 'died'], 
           colors=['yellowgreen', 'black'])

# %%
sex_df = df['sex'].value_counts()

fig, ax =plt.subplots()

_ = ax.pie(x=sex_df.values, 
           labels=sex_df.index, 
           colors=['navy', 'maroon'])

# %% [markdown]
# ## Mengenal Bar Chart

# %%
sex_df = df['sex'].value_counts()
print(f'index: {sex_df.index}')
print(f'values: {sex_df.values}')

# %%
fig, ax = plt.subplots()

_ = ax.bar(sex_df.index, sex_df.values)

# %% [markdown]
# # End of Presentation
#
# ![](./images/pip_install_coffee.png)
#
# ### Happy Pythoning :)
